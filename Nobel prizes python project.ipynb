# %% [markdown]
# **Python Blok Projesi**<p><img style="float: right;margin:5px 20px 5px 1px; max-width:250px" src="https://assets.datacamp.com/production/project_441/img/Nobel_Prize.png"></p>
#
# <p>Nobel Ödülü belki de dünyanın en tanınmış bilimsel ödülüdür. Her yıl kimya, edebiyat, fizik, tıp, ekonomi ve barış alanlarında bilim insanlarına ve akademisyenlere verilmektedir. Bu projede, Nobel Ödülü kazananları inceleyeceğiz. </p>

# %% [markdown]
# ## Proje Soruları
#
# 1. Nobel Ödüllerini en çok kazanan ilk on ülkeyi bulunuz.
# 2. Nobel Ödüllerini kazanan ilk kadınları listeleyiniz.
# 3. Nobel Ödüllerini kazanan ilk erkekleri listeleyiniz.
# 4. Nobel ödülünü en çok kazanan ülkenin hangi yıldan itibaren hakimiyet sağladığını görselleştirip bu hakimiyette rol oynayan şeyler nelerdir? İçgörülerinizi paylaşır mısınız?
# 5. Nobel Ödülü kazananların cinsiyetlerini, yaşlarını, ödül kategorisi ve yılları kullanarak görselleştiriniz.(Her bir ödül kategorisi için ayrı grafik gösteriniz) Çıkan sonuçlara göre görseli yorumlayınız.
# 6. 1938-1945 yılı arasında Nobel Ödülü kazananların kategorilerini ve ülkelerini görselleştirip yorumlayınız.
# 7. 1947-1991 yılları arasında Nobel Ödülü kazananların kategorilerini ve ülkelerini görselleştirip yorumlayınız.(Her kategori için ayrı bir grafik olması istenmektedir)
# 8. Kimya, Edebiyat, Barış, Fizik ve Tıp kategorilerindeki 2000 sonrasındaki kişilerin ülkelerini, yaşlarını görselleştirin.(Her bir Kategori için ayrı görselleştirme yapılması istenmektedir) Veriyi yorumlayınız.

# %% [markdown]
#  <span style="font-size: 24px; color: blue;">                 PROJE SORULARININ ÇÖZÜMLERİ</span>

# %% [markdown]
# Öncelikle nobel.csv dosyasıyla ilgili verileri araştıralım.

# %%
import pandas as pd

# %%
df=pd.read_csv("nobel.csv")
df
# Out:
#      year    category                                           prize  \
# 0    1901   Chemistry               The Nobel Prize in Chemistry 1901
# 1    1901  Literature              The Nobel Prize in Literature 1901
# 2    1901    Medicine  The Nobel Prize in Physiology or Medicine 1901
# 3    1901       Peace                      The Nobel Peace Prize 1901
# 4    1901       Peace                      The Nobel Peace Prize 1901
# ..    ...         ...                                             ...
# 906  2016    Medicine  The Nobel Prize in Physiology or Medicine 2016
# 907  2016       Peace                      The Nobel Peace Prize 2016
# 908  2016     Physics                 The Nobel Prize in Physics 2016
# 909  2016     Physics                 The Nobel Prize in Physics 2016
# 910  2016     Physics                 The Nobel Prize in Physics 2016
#
#                                             motivation prize_share  \
# ...

# %%
df.columns
# Out:
# Index(['year', 'category', 'prize', 'motivation', 'prize_share', 'laureate_id',
#        'laureate_type', 'full_name', 'birth_date', 'birth_city',
#        'birth_country', 'sex', 'organization_name', 'organization_city',
#        'organization_country', 'death_date', 'death_city', 'death_country'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 911 entries, 0 to 910
# Data columns (total 18 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   year                  911 non-null    int64
#  1   category              911 non-null    object
#  2   prize                 911 non-null    object
#  3   motivation            823 non-null    object
#  4   prize_share           911 non-null    object
#  5   laureate_id           911 non-null    int64
#  6   laureate_type         911 non-null    object
#  7   full_name             911 non-null    object
#  8   birth_date            883 non-null    object
#  9   birth_city            883 non-null    object
#  10  birth_country         885 non-null    object
#  11  sex                   885 non-null    object
#  12  organization_name     665 non-null    object
#  13  organization_city     667 non-null    object
#  14  organization_country  667 non-null    object
# ...

# %%
df.shape
# Out:
# (911, 18)

# %%
df.isnull().sum()
# Out:
# year                      0
# category                  0
# prize                     0
# motivation               88
# prize_share               0
# laureate_id               0
# laureate_type             0
# full_name                 0
# birth_date               28
# birth_city               28
# birth_country            26
# sex                      26
# organization_name       246
# organization_city       244
# organization_country    244
# death_date              318
# death_city              335
# death_country           329
# dtype: int64

# %% [markdown]
# <span style="font-size: 16px; color: blue;">1. Nobel Ödüllerini en çok kazanan ilk on ülkeyi bulunuz.</span>

# %%
df.groupby('organization_country').count()
# Out:
#                                      year  category  prize  motivation  \
# organization_country
# Alsace (then Germany, now France)       1         1      1           1
# Argentina                               2         2      2           2
# Australia                               5         5      5           5
# Austria                                 6         6      6           6
# Belgium                                 5         5      5           5
# Canada                                  7         7      7           7
# China                                   1         1      1           1
# Czechoslovakia                          1         1      1           1
# Denmark                                 8         8      8           8
# Federal Republic of Germany            23        23     23          23
# Finland                                 1         1      1           1
# France                                 36        36     36          35
# ...

# %%
df.groupby('organization_country')[['prize']].count()
# Out:
#                                      prize
# organization_country
# Alsace (then Germany, now France)        1
# Argentina                                2
# Australia                                5
# Austria                                  6
# Belgium                                  5
# Canada                                   7
# China                                    1
# Czechoslovakia                           1
# Denmark                                  8
# Federal Republic of Germany             23
# Finland                                  1
# France                                  36
# Germany                                 43
# Hungary                                  1
# India                                    1
# Ireland                                  1
# Israel                                   5
# Italy                                    6
# Japan                                   16
# Netherlands                             11
# ...

# %%
prize_counts=df.groupby('organization_country')[['prize']].count()

# %%
prize_counts_sorted=prize_counts.sort_values(by='prize',ascending=False)

# %%
prize_counts_sorted.head(10)
# Out:
#                                      prize
# organization_country
# United States of America               341
# United Kingdom                          89
# Germany                                 43
# France                                  36
# Federal Republic of Germany             23
# Switzerland                             21
# Sweden                                  17
# Japan                                   16
# Netherlands                             11
# Union of Soviet Socialist Republics      9

# %% [markdown]
# <span style="font-size: 16px; color: blue;">2. Nobel Ödüllerini kazanan ilk kadınları listeleyiniz.</span>

# %%
df.groupby('sex')[['year']].count()
# Out:
#         year
# sex
# Female    49
# Male     836

# %%
female_data=df[df['sex']=="Female"]

# %%
female_data
# Out:
#      year    category                                              prize  \
# 19   1903     Physics                    The Nobel Prize in Physics 1903
# 29   1905       Peace                         The Nobel Peace Prize 1905
# 51   1909  Literature                 The Nobel Prize in Literature 1909
# 62   1911   Chemistry                  The Nobel Prize in Chemistry 1911
# 128  1926  Literature                 The Nobel Prize in Literature 1926
# 141  1928  Literature                 The Nobel Prize in Literature 1928
# 160  1931       Peace                         The Nobel Peace Prize 1931
# 179  1935   Chemistry                  The Nobel Prize in Chemistry 1935
# 198  1938  Literature                 The Nobel Prize in Literature 1938
# 218  1945  Literature                 The Nobel Prize in Literature 1945
# 229  1946       Peace                         The Nobel Peace Prize 1946
# 235  1947    Medicine     The Nobel Prize in Physiology or Medicine 1947
# ...

# %% [markdown]
# <span style="font-size: 16px; color: blue;">3. Nobel Ödüllerini kazanan ilk erkekleri listeleyiniz.</span>

# %%
male_data=df[df['sex']=="Male"]
male_data
# Out:
#      year    category                                           prize  \
# 0    1901   Chemistry               The Nobel Prize in Chemistry 1901
# 1    1901  Literature              The Nobel Prize in Literature 1901
# 2    1901    Medicine  The Nobel Prize in Physiology or Medicine 1901
# 3    1901       Peace                      The Nobel Peace Prize 1901
# 4    1901       Peace                      The Nobel Peace Prize 1901
# ..    ...         ...                                             ...
# 906  2016    Medicine  The Nobel Prize in Physiology or Medicine 2016
# 907  2016       Peace                      The Nobel Peace Prize 2016
# 908  2016     Physics                 The Nobel Prize in Physics 2016
# 909  2016     Physics                 The Nobel Prize in Physics 2016
# 910  2016     Physics                 The Nobel Prize in Physics 2016
#
#                                             motivation prize_share  \
# ...

# %% [markdown]
# <span style="font-size: 16px; color: blue;">4. Nobel ödülünü en çok kazanan ülkenin hangi yıldan itibaren hakimiyet sağladığını görselleştirip bu hakimiyette rol oynayan şeyler nelerdir? İçgörülerinizi paylaşır mısınız?</span>

# %%
prize_counts_sorted=prize_counts.sort_values(by='prize',ascending=False)
prize_counts_sorted
# Out:
#                                      prize
# organization_country
# United States of America               341
# United Kingdom                          89
# Germany                                 43
# France                                  36
# Federal Republic of Germany             23
# Switzerland                             21
# Sweden                                  17
# Japan                                   16
# Netherlands                             11
# Union of Soviet Socialist Republics      9
# Denmark                                  8
# Canada                                   7
# Austria                                  6
# Italy                                    6
# Belgium                                  5
# Australia                                5
# Israel                                   5
# Norway                                   5
# Russia                                   3
# Argentina                                2
# ...

# %%
top_3_countries=prize_counts_sorted.head(3)

# %%
import matplotlib.pyplot as plt

# %%
top_3_countries.plot(kind='bar',color='orange',stacked=True)
plt.title('Top 3 Countries With Most Awards')
plt.xlabel(' ')
plt.ylabel('Number of Prizes')
plt.xticks(rotation=0)
plt.show()

# %%
most_prizes_country=df[df['organization_country']=="United States of America"]
most_prizes_country
# Out:
#      year   category                                              prize  \
# 42   1907    Physics                    The Nobel Prize in Physics 1907
# 71   1912   Medicine     The Nobel Prize in Physiology or Medicine 1912
# 79   1914  Chemistry                  The Nobel Prize in Chemistry 1914
# 117  1923    Physics                    The Nobel Prize in Physics 1923
# 138  1927    Physics                    The Nobel Prize in Physics 1927
# ..    ...        ...                                                ...
# 903  2016  Economics  The Sveriges Riksbank Prize in Economic Scienc...
# 904  2016  Economics  The Sveriges Riksbank Prize in Economic Scienc...
# 908  2016    Physics                    The Nobel Prize in Physics 2016
# 909  2016    Physics                    The Nobel Prize in Physics 2016
# 910  2016    Physics                    The Nobel Prize in Physics 2016
#
#                                             motivation prize_share  \
# ...

# %%
prize_counts_by_year=df.groupby('year')[['prize']].count()
prize_counts_by_year
# Out:
#       prize
# year
# 1901      6
# 1902      7
# 1903      7
# 1904      6
# 1905      5
# ...     ...
# 2012     10
# 2013     13
# 2014     13
# 2015     11
# 2016     11
#
# [113 rows x 1 columns]

# %%
prize_counts_by_year_USA=most_prizes_country.groupby('year')[['prize']].count()
prize_counts_by_year_USA
# Out:
#       prize
# year
# 1907      1
# 1912      1
# 1914      1
# 1923      1
# 1927      1
# ...     ...
# 2012      4
# 2013      8
# 2014      3
# 2015      4
# 2016      6
#
# [86 rows x 1 columns]

# %%
prize_counts_by_year_USA=most_prizes_country.groupby('year')[['prize']].count()
prize_counts_by_year_USA.plot(kind='line', marker='o')
plt.title('Number of Prizes Received by USA Organizations per Year')
plt.xlabel(' ')
plt.ylabel('Number of Prizes')
plt.xticks(range(1900, 2021, 5), rotation=45)
plt.show()

# %%
most_prizes_country2=df[df['organization_country']=="United Kingdom"]
most_prizes_country2
# Out:
#      year   category                                           prize  \
# 8    1902   Medicine  The Nobel Prize in Physiology or Medicine 1902
# 20   1904  Chemistry               The Nobel Prize in Chemistry 1904
# 25   1904    Physics                 The Nobel Prize in Physics 1904
# 36   1906    Physics                 The Nobel Prize in Physics 1906
# 43   1908  Chemistry               The Nobel Prize in Chemistry 1908
# ..    ...        ...                                             ...
# 839  2010    Physics                 The Nobel Prize in Physics 2010
# 858  2012   Medicine  The Nobel Prize in Physiology or Medicine 2012
# 875  2013    Physics                 The Nobel Prize in Physics 2013
# 881  2014   Medicine  The Nobel Prize in Physiology or Medicine 2014
# 889  2015  Chemistry               The Nobel Prize in Chemistry 2015
#
#                                             motivation prize_share  \
# 8    "for his work on malaria, by which he has show...         1/1
# ...

# %%
prize_counts_by_year_UK=most_prizes_country2.groupby('year')[['prize']].count()
prize_counts_by_year_UK
# Out:
#       prize
# year
# 1902      1
# 1904      2
# 1906      1
# 1908      1
# 1909      1
# 1915      2
# 1917      1
# 1921      1
# 1922      2
# 1927      1
# 1928      1
# 1929      2
# 1932      2
# 1933      1
# 1935      1
# 1936      1
# 1937      2
# 1945      3
# 1947      2
# 1948      1
# 1950      1
# 1951      1
# 1952      2
# 1953      1
# 1954      1
# 1956      1
# 1957      1
# 1958      1
# 1960      1
# 1962      4
# 1963      2
# 1964      1
# 1967      2
# 1969      1
# 1970      1
# 1971      1
# 1972      2
# 1973      3
# 1974      2
# 1975      2
# 1977      2
# 1978      1
# 1979      1
# 1980      1
# 1982      2
# 1984      2
# 1988      1
# 1996      2
# 1997      1
# 1998      1
# 2001      2
# 2002      1
# 2003      1
# 2007      1
# 2009      2
# 2010      4
# 2012      1
# 2013      1
# 2014      1
# 2015      1

# %%
prize_counts_by_year_UK=most_prizes_country2.groupby('year')[['prize']].count()
prize_counts_by_year_UK.plot(kind='line', marker='o', color='red')
plt.title('Number of Prizes Received by UK Organizations per Year')
plt.xlabel(' ')
plt.ylabel('Number of Prizes')
plt.xticks(range(1900, 2021, 5), rotation=45)
plt.show()

# %%
most_prizes_country3=df[df['organization_country']=="Germany"]
most_prizes_country3
# Out:
#      year   category                                           prize  \
# 0    1901  Chemistry               The Nobel Prize in Chemistry 1901
# 2    1901   Medicine  The Nobel Prize in Physiology or Medicine 1901
# 5    1901    Physics                 The Nobel Prize in Physics 1901
# 6    1902  Chemistry               The Nobel Prize in Chemistry 1902
# 26   1905  Chemistry               The Nobel Prize in Chemistry 1905
# 28   1905   Medicine  The Nobel Prize in Physiology or Medicine 1905
# 30   1905    Physics                 The Nobel Prize in Physics 1905
# 37   1907  Chemistry               The Nobel Prize in Chemistry 1907
# 46   1908   Medicine  The Nobel Prize in Physiology or Medicine 1908
# 50   1909  Chemistry               The Nobel Prize in Chemistry 1909
# 57   1910  Chemistry               The Nobel Prize in Chemistry 1910
# 59   1910   Medicine  The Nobel Prize in Physiology or Medicine 1910
# 67   1911    Physics                 The Nobel Prize in Physics 1911
# ...

# %%
prize_counts_by_year_G=most_prizes_country3.groupby('year')[['prize']].count()
prize_counts_by_year_G
# Out:
#       prize
# year
# 1901      3
# 1902      1
# 1905      3
# 1907      1
# 1908      1
# 1909      1
# 1910      2
# 1911      1
# 1914      1
# 1915      1
# 1918      2
# 1919      1
# 1920      1
# 1921      1
# 1922      1
# 1925      3
# 1927      1
# 1928      1
# 1930      1
# 1931      3
# 1932      1
# 1933      1
# 1935      1
# 1936      1
# 1938      1
# 1939      2
# 1944      1
# 2005      1
# 2007      2
# 2008      1
# 2014      1

# %%
prize_counts_by_year_G=most_prizes_country3.groupby('year')[['prize']].count()
prize_counts_by_year_G.plot(kind='line', marker='o', color='yellow')
plt.title('Number of Prizes Received by Germany Organizations per Year')
plt.xlabel(' ')
plt.ylabel('Number of Prizes')
plt.xticks(range(1900, 2021, 5), rotation=45)
plt.show()

# %% [markdown]
# <span style="font-size: 16px; color: black;">**YORUM:** Nobel ödülünü kazanan ilk 3 ülkeden Almanya yaklaşık 1940lara kadar ödül sayısı en fazla olan ülkeyken 1940-2001 arasında bir durgunluk oluşmuş, USA nın grafiğini incelediğimde 1940-2001 arasında nobel ödüllerinde hakimiyet sağladığını gördüm. Bu durumu Almanyadan Amerikaya beyin göçü şüphesiyle araştırdığımda zamanlamanın 2.Dünya savaşının hemen öncesine denk geldiğini ve Albert Einstein da dahil Almanyadaki bir çok bilim insanın Hitlerden kaçıp Amerikaya yerleştiği bilgisine ulaştım. Bu sonuçla en çok ödüle layık görülen Amerikanın bu tarihlerde nobel ödülü hakimiyeti artmıştır.</span>

# %% [markdown]
# <span style="font-size: 16px; color: blue;">5. Nobel Ödülü kazananların cinsiyetlerini, yaşlarını, ödül kategorisi ve yılları kullanarak görselleştiriniz.(Her bir ödül kategorisi için ayrı grafik gösteriniz) Çıkan sonuçlara göre görseli yorumlayınız.</span>

# %%
# Cinsiyetlerin yıllara göre dağılımını inceleyelim.

# %%
female_data=df[df['sex']=="Female"]
female_counts_by_year=female_data.groupby('year')[['prize']].count()
female_counts_by_year
# Out:
#       prize
# year
# 1903      1
# 1905      1
# 1909      1
# 1911      1
# 1926      1
# 1928      1
# 1931      1
# 1935      1
# 1938      1
# 1945      1
# 1946      1
# 1947      1
# 1963      1
# 1964      1
# 1966      1
# 1976      2
# 1977      1
# 1979      1
# 1982      1
# 1983      1
# 1986      1
# 1988      1
# 1991      2
# 1992      1
# 1993      1
# 1995      1
# 1996      1
# 1997      1
# 2003      1
# 2004      3
# 2007      1
# 2008      1
# 2009      5
# 2011      3
# 2013      1
# 2014      2
# 2015      2

# %%
male_data=df[df['sex']=="Male"]
male_counts_by_year=male_data.groupby('year')[['prize']].count()
male_counts_by_year
# Out:
#       prize
# year
# 1901      6
# 1902      7
# 1903      6
# 1904      5
# 1905      4
# ...     ...
# 2012      9
# 2013     11
# 2014     11
# 2015      8
# 2016     11
#
# [113 rows x 1 columns]

# %%
total_prize_counts_by_year=male_counts_by_year.merge(female_counts_by_year,how='outer',on='year', suffixes=('_male', '_female'))
total_prize_counts_by_year
# Out:
#       prize_male  prize_female
# year
# 1901           6           NaN
# 1902           7           NaN
# 1903           6           1.0
# 1904           5           NaN
# 1905           4           1.0
# ...          ...           ...
# 2012           9           NaN
# 2013          11           1.0
# 2014          11           2.0
# 2015           8           2.0
# 2016          11           NaN
#
# [113 rows x 2 columns]

# %%
total_prize_counts_by_year.plot(kind='line',marker='o')
plt.xlabel(' ')
plt.ylabel('Prize Counts')
plt.title('Distribution of gender by years')
plt.xticks(range(1900, 2021, 5), rotation=45)
plt.legend(['Male', 'Female'])
plt.show()

# %% [markdown]
# <span style="font-size: 16px; color: black;">**YORUM:** Bu grafikte yıllara göre Nobel ödülü sayısının cinsiyet dağılımında erkek katılımcılarda yoğun olduğunu görüyorum.Kadınlar için 2000lerden sonra öncesine göre ödül sayısında artışı yaşanmıştır.</span>

# %%
# Her bir kategorinin yıllara göre ödül sayısını inceleyelim.

# %%
df.groupby('category').count()
# Out:
#             year  prize  motivation  prize_share  laureate_id  laureate_type  \
# category
# Chemistry    175    175         175          175          175            175
# Economics     78     78          78           78           78             78
# Literature   113    113         113          113          113            113
# Medicine     211    211         211          211          211            211
# Peace        130    130          42          130          130            130
# Physics      204    204         204          204          204            204
#
#             full_name  birth_date  birth_city  birth_country  sex  \
# category
# Chemistry         175         174         175            175  175
# Economics          78          78          78             78   78
# Literature        113         113         112            113  113
# Medicine          211         211         211            211  211
# Peace             130         104         103            104  104
# ...

# %%
chemistry_data=df[df['category']=="Chemistry"]
chemistry_counts_by_year=chemistry_data.groupby('year')[['prize']].count()
chemistry_counts_by_year
# Out:
#       prize
# year
# 1901      1
# 1902      1
# 1903      1
# 1904      1
# 1905      1
# ...     ...
# 2012      2
# 2013      3
# 2014      3
# 2015      3
# 2016      3
#
# [108 rows x 1 columns]

# %%
plt.plot(chemistry_counts_by_year.index, chemistry_counts_by_year['prize'],color='blue', marker='o', linestyle='-')
plt.xlabel(' ')
plt.ylabel('Number of Prizes')
plt.title('Chemistry Nobel Prizes by Year')
plt.xticks(range(1900, 2021, 10), rotation=45)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# <span style="font-size: 16px; color: black;">**YORUM:** Yıllar arttıkça genel bir artış olmuş fakat 1960 lardan sonra çoğu yılda 3 ödül birden alınmış bu alandaki çalışmaların artışı buna sebep olmuş olabilir.</span>

# %%
economics_data=df[df['category']=="Economics"]
economics_counts_by_year=economics_data.groupby('year')[['prize']].count()
economics_counts_by_year
# Out:
#       prize
# year
# 1969      2
# 1970      1
# 1971      1
# 1972      2
# 1973      1
# 1974      2
# 1975      2
# 1976      1
# 1977      2
# 1978      1
# 1979      2
# 1980      1
# 1981      1
# 1982      1
# 1983      1
# 1984      1
# 1985      1
# 1986      1
# 1987      1
# 1988      1
# 1989      1
# 1990      3
# 1991      1
# 1992      1
# 1993      2
# 1994      3
# 1995      1
# 1996      2
# 1997      2
# 1998      1
# 1999      1
# 2000      2
# 2001      3
# 2002      2
# 2003      2
# 2004      2
# 2005      2
# 2006      1
# 2007      3
# 2008      1
# 2009      2
# 2010      3
# 2011      2
# 2012      2
# 2013      3
# 2014      1
# 2015      1
# 2016      2

# %%
plt.plot(economics_counts_by_year.index, economics_counts_by_year['prize'],color='red', marker='o', linestyle='-')
plt.xlabel(' ')
plt.ylabel('Number of Prizes')
plt.title('Economics Nobel Prizes by Year')
plt.xticks(range(1900, 2021, 10), rotation=45)
plt.show()

# %% [markdown]
# <span style="font-size: 16px; color: black;">**YORUM:** Grafikte 1969 lara kadar bu alanda ödül alınmamış ve sebebini araştırdığımda Nobel ödülleri kurucusu Alfred Nobelin vasiyetinde ödülün 5 alanda verilmesi istenmiş fakat kuruluş 1968 de ekonomi alanını da ekleyerek Nobel ödüllerinde güncelleme yapılmış.1990 lardan sonra ödül sayısında önceki yıllara göre belirgin bir artış yaşanmıştır.<span/>

# %%
literature_data=df[df['category']=="Literature"]
literature_counts_by_year=literature_data.groupby('year')[['prize']].count()
literature_counts_by_year
# Out:
#       prize
# year
# 1901      1
# 1902      1
# 1903      1
# 1904      2
# 1905      1
# ...     ...
# 2012      1
# 2013      1
# 2014      1
# 2015      1
# 2016      1
#
# [109 rows x 1 columns]

# %%
plt.plot(literature_counts_by_year.index, literature_counts_by_year['prize'],color='salmon', marker='o', linestyle='-')
plt.xlabel(' ')
plt.ylabel('Number of Prizes')
plt.title('Literature Nobel Prizes by Year')
plt.xticks(range(1900, 2021, 10), rotation=45)
plt.show()

# %% [markdown]
# <span style="font-size: 16px; color: black;">**YORUM:** Yıllar veri aralığımızda yani yaklaşık 120 yılda çok yükseliş veya düşüşün olmadığı bir grafik inceliyoruz, 2.dünya savaşı dönemi ve birkaç yıl hariç tüm yıllarda ödül alınmış fakat çoğunlukla 1 ödül sayısı olması edebiyat alanında bazı kriterlerin fazla göreceli olmasından kaynaklanmış olabilir.<span/>

# %%
medicine_data=df[df['category']=="Medicine"]
medicine_counts_by_year=medicine_data.groupby('year')[['prize']].count()
medicine_counts_by_year
# Out:
#       prize
# year
# 1901      1
# 1902      1
# 1903      1
# 1904      1
# 1905      1
# ...     ...
# 2012      2
# 2013      3
# 2014      3
# 2015      3
# 2016      1
#
# [107 rows x 1 columns]

# %%
plt.plot(medicine_counts_by_year.index, medicine_counts_by_year['prize'],color='green',marker='o', linestyle='-')
plt.xlabel(' ')
plt.ylabel('Number of Prizes')
plt.title('Medicine Nobel Prizes by Year')
plt.xticks(range(1900, 2021, 10), rotation=45)
plt.show()

# %% [markdown]
# <span style="font-size: 16px; color: black;">**YORUM:** Genel olarak bu alanda hemen hemen 1. ve 2. dünya savaşları dönemleri haricinde ödül alınmıştır.1945lerden sonra gelişen dünyada tıpta araştırma ve gelişim desteklendikçe ödül sayısında önceki yıllara göre artış yaşanmıştır.<span/>

# %%
peace_data=df[df['category']=="Peace"]
peace_counts_by_year=peace_data.groupby('year')[['prize']].count()
peace_counts_by_year
# Out:
#       prize
# year
# 1901      2
# 1902      2
# 1903      1
# 1904      1
# 1905      1
# ...     ...
# 2012      1
# 2013      1
# 2014      2
# 2015      1
# 2016      1
#
# [97 rows x 1 columns]

# %%
plt.plot(peace_counts_by_year.index,peace_counts_by_year['prize'],marker='o',color="grey" ,linestyle='-')
plt.xlabel(' ')
plt.ylabel('Number of Prizes')
plt.title('Peace Nobel Prizes by Year')
plt.xticks(range(1900, 2021, 10), rotation=45)
plt.show()

# %% [markdown]
# <span style="font-size: 16px; color: black;">**YORUM:** 1900 lü yıllardan itibaren barış alanında ödüller var,savaş dönemleri ve birkaç yıl hariç.Aynı yıl için üç ödüle 2 kere ulaşılmış,ilkinde ödül sahipleri 1994 te Filistinli lider Yaser Arafat, İsrail Başbakanı İzak Rabin ve İsrail Dışişleri Bakanı Şimon Peres e 'Orta Doğuda barış yaratma çabaları nedeniyle' iken diğer üç ödül 2011 yılında 'Kadınların güvenliğini sağlama ve barış inşa etme çalışmalarına tam katılım hakları için verdikleri şiddetsiz mücadele' nedeniyle üç kadına aittir.<span/>

# %%
physics_data=df[df['category']=="Physics"]
physics_counts_by_year=physics_data.groupby('year')[['prize']].count()
physics_counts_by_year
# Out:
#       prize
# year
# 1901      1
# 1902      2
# 1903      3
# 1904      1
# 1905      1
# ...     ...
# 2012      2
# 2013      2
# 2014      3
# 2015      2
# 2016      3
#
# [110 rows x 1 columns]

# %%
plt.plot(physics_counts_by_year.index, physics_counts_by_year['prize'],color='orange',marker='o', linestyle='-')
plt.xlabel(' ')
plt.ylabel('Number of Prizes')
plt.title('Physics Nobel Prizes by Year')
plt.xticks(range(1900, 2021, 10), rotation=45)
plt.show()

# %% [markdown]
# <span style="font-size: 16px; color: black;">**YORUM:** Tıp alanından sonra en çok ödül alınan 2.alanın fizik olduğunu söyleyebilirim.Bilimsel çalışmalar desteklendiği ve geliştiği sürece bu alanlardaki ödül sayıları da artmıştır.1955lerden sonra daha fazla bir artış olmuştur.<span/>

# %%
# Her kategoriyi cinsiyet bazında inceleyelim.

# %%
male_data=df[df['sex']=="Male"]
male_counts_by_category=male_data.groupby('category')[['prize']].count()
male_counts_by_category
# Out:
#             prize
# category
# Chemistry     171
# Economics      77
# Literature     99
# Medicine      199
# Peace          88
# Physics       202

# %%
female_data=df[df['sex']=="Female"]
female_counts_by_category=female_data.groupby('category')[['prize']].count()
female_counts_by_category
# Out:
#             prize
# category
# Chemistry       4
# Economics       1
# Literature     14
# Medicine       12
# Peace          16
# Physics         2

# %%
male_data=df[df['sex']=="Male"]
male_counts_by_category=male_data.groupby('category')[['prize']].count()
female_data=df[df['sex']=="Female"]
female_counts_by_category=female_data.groupby('category')[['prize']].count()
fig, ax = plt.subplots()
bar1 = plt.bar(male_counts_by_category.index, male_counts_by_category['prize'].values)
bar2 = plt.bar(female_counts_by_category.index, female_counts_by_category['prize'].values,
               bottom=male_counts_by_category['prize'].values)
plt.xlabel(' ')
plt.ylabel('Prize Counts')
plt.title('Counts by category and gender')
plt.xticks(rotation=45)
plt.legend((bar1, bar2), ('Male', 'Female'))

plt.show()

# %% [markdown]
# <span style="font-size: 16px; color: black;">**YORUM:** Nobel ödüllerinde erkekler tüm alanlarda açık ara farkla kadınlardan önde olmuştur.Kadınların en fazla ödül aldığı alanlar barış ve edebiyat iken en az ödül aldığı alanlar ekonomi ve fizik olmuş. Erkeklerin en fazla ödül adığı alanlar tıp ve fizik iken en az ödül aldığı alanlar ekonomi ve barış olmuştur.<span/>

# %%
# Ödül kazananların yaşlarını yıllara göre inceleyelim.

# %%
data_age=df[['year','prize','category','organization_country','birth_date','death_date']]
data_age
# Out:
#      year                                           prize    category  \
# 0    1901               The Nobel Prize in Chemistry 1901   Chemistry
# 1    1901              The Nobel Prize in Literature 1901  Literature
# 2    1901  The Nobel Prize in Physiology or Medicine 1901    Medicine
# 3    1901                      The Nobel Peace Prize 1901       Peace
# 4    1901                      The Nobel Peace Prize 1901       Peace
# ..    ...                                             ...         ...
# 906  2016  The Nobel Prize in Physiology or Medicine 2016    Medicine
# 907  2016                      The Nobel Peace Prize 2016       Peace
# 908  2016                 The Nobel Prize in Physics 2016     Physics
# 909  2016                 The Nobel Prize in Physics 2016     Physics
# 910  2016                 The Nobel Prize in Physics 2016     Physics
#
#          organization_country  birth_date  death_date
# 0                     Germany  1852-08-30  1911-03-01
# ...

# %%
data_age.dropna(subset=['birth_date'],inplace=True)
# Out:
# C:\Users\HGA\AppData\Local\Temp\ipykernel_11092\904766559.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_age.dropna(subset=['birth_date'],inplace=True)

# %%
data_age['birth_date']=pd.to_datetime(data_age['birth_date'])
# Out:
# C:\Users\HGA\AppData\Local\Temp\ipykernel_11092\617402985.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_age['birth_date']=pd.to_datetime(data_age['birth_date'])

# %%
data_age
# Out:
#      year                                           prize    category  \
# 0    1901               The Nobel Prize in Chemistry 1901   Chemistry
# 1    1901              The Nobel Prize in Literature 1901  Literature
# 2    1901  The Nobel Prize in Physiology or Medicine 1901    Medicine
# 3    1901                      The Nobel Peace Prize 1901       Peace
# 4    1901                      The Nobel Peace Prize 1901       Peace
# ..    ...                                             ...         ...
# 906  2016  The Nobel Prize in Physiology or Medicine 2016    Medicine
# 907  2016                      The Nobel Peace Prize 2016       Peace
# 908  2016                 The Nobel Prize in Physics 2016     Physics
# 909  2016                 The Nobel Prize in Physics 2016     Physics
# 910  2016                 The Nobel Prize in Physics 2016     Physics
#
#          organization_country birth_date  death_date
# 0                     Germany 1852-08-30  1911-03-01
# ...

# %%
data_age.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 883 entries, 0 to 910
# Data columns (total 6 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   year                  883 non-null    int64
#  1   prize                 883 non-null    object
#  2   category              883 non-null    object
#  3   organization_country  665 non-null    object
#  4   birth_date            883 non-null    datetime64[ns]
#  5   death_date            593 non-null    object
# dtypes: datetime64[ns](1), int64(1), object(4)
# memory usage: 48.3+ KB

# %%
import pandas as pd
from datetime import date

# Bugünün tarihini alma
bugun = date.today()

print(bugun)
# Out:
# 2025-02-19

# %%
data_age['death_date'].fillna(bugun,inplace=True)
# Out:
# C:\Users\HGA\AppData\Local\Temp\ipykernel_11092\2281878136.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_age['death_date'].fillna(bugun,inplace=True)

# %%
data_age['death_date']= pd.to_datetime(data_age['death_date'])
# Out:
# C:\Users\HGA\AppData\Local\Temp\ipykernel_11092\3840719165.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_age['death_date']= pd.to_datetime(data_age['death_date'])

# %%
data_age
# Out:
#      year                                           prize    category  \
# 0    1901               The Nobel Prize in Chemistry 1901   Chemistry
# 1    1901              The Nobel Prize in Literature 1901  Literature
# 2    1901  The Nobel Prize in Physiology or Medicine 1901    Medicine
# 3    1901                      The Nobel Peace Prize 1901       Peace
# 4    1901                      The Nobel Peace Prize 1901       Peace
# ..    ...                                             ...         ...
# 906  2016  The Nobel Prize in Physiology or Medicine 2016    Medicine
# 907  2016                      The Nobel Peace Prize 2016       Peace
# 908  2016                 The Nobel Prize in Physics 2016     Physics
# 909  2016                 The Nobel Prize in Physics 2016     Physics
# 910  2016                 The Nobel Prize in Physics 2016     Physics
#
#          organization_country birth_date death_date
# 0                     Germany 1852-08-30 1911-03-01
# ...

# %%
data_age.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 883 entries, 0 to 910
# Data columns (total 6 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   year                  883 non-null    int64
#  1   prize                 883 non-null    object
#  2   category              883 non-null    object
#  3   organization_country  665 non-null    object
#  4   birth_date            883 non-null    datetime64[ns]
#  5   death_date            883 non-null    datetime64[ns]
# dtypes: datetime64[ns](2), int64(1), object(3)
# memory usage: 48.3+ KB

# %%
data_age['age']=data_age['death_date'] - data_age['birth_date']
# Out:
# C:\Users\HGA\AppData\Local\Temp\ipykernel_11092\2911687473.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_age['age']=data_age['death_date'] - data_age['birth_date']

# %%
data_age
# Out:
#      year                                           prize    category  \
# 0    1901               The Nobel Prize in Chemistry 1901   Chemistry
# 1    1901              The Nobel Prize in Literature 1901  Literature
# 2    1901  The Nobel Prize in Physiology or Medicine 1901    Medicine
# 3    1901                      The Nobel Peace Prize 1901       Peace
# 4    1901                      The Nobel Peace Prize 1901       Peace
# ..    ...                                             ...         ...
# 906  2016  The Nobel Prize in Physiology or Medicine 2016    Medicine
# 907  2016                      The Nobel Peace Prize 2016       Peace
# 908  2016                 The Nobel Prize in Physics 2016     Physics
# 909  2016                 The Nobel Prize in Physics 2016     Physics
# 910  2016                 The Nobel Prize in Physics 2016     Physics
#
#          organization_country birth_date death_date        age
# 0                     Germany 1852-08-30 1911-03-01 21366 days
# ...

# %%
data_age['age']=data_age['age']//365
data_age
# Out:
# C:\Users\HGA\AppData\Local\Temp\ipykernel_11092\1253288087.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_age['age']=data_age['age']//365
#      year                                           prize    category  \
# 0    1901               The Nobel Prize in Chemistry 1901   Chemistry
# 1    1901              The Nobel Prize in Literature 1901  Literature
# 2    1901  The Nobel Prize in Physiology or Medicine 1901    Medicine
# 3    1901                      The Nobel Peace Prize 1901       Peace
# 4    1901                      The Nobel Peace Prize 1901       Peace
# ..    ...                                             ...         ...
# 906  2016  The Nobel Prize in Physiology or Medicine 2016    Medicine
# ...

# %%
data_age['age']=data_age['age'].dt.total_seconds() / (24 * 60 * 60)
data_age['age']= data_age['age'].astype('int64')
# Out:
# C:\Users\HGA\AppData\Local\Temp\ipykernel_11092\2942765769.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_age['age']=data_age['age'].dt.total_seconds() / (24 * 60 * 60)
# C:\Users\HGA\AppData\Local\Temp\ipykernel_11092\2942765769.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_age['age']= data_age['age'].astype('int64')

# %%
data_age.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 883 entries, 0 to 910
# Data columns (total 7 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   year                  883 non-null    int64
#  1   prize                 883 non-null    object
#  2   category              883 non-null    object
#  3   organization_country  665 non-null    object
#  4   birth_date            883 non-null    datetime64[ns]
#  5   death_date            883 non-null    datetime64[ns]
#  6   age                   883 non-null    int64
# dtypes: datetime64[ns](2), int64(2), object(3)
# memory usage: 55.2+ KB

# %%
data_age
# Out:
#      year                                           prize    category  \
# 0    1901               The Nobel Prize in Chemistry 1901   Chemistry
# 1    1901              The Nobel Prize in Literature 1901  Literature
# 2    1901  The Nobel Prize in Physiology or Medicine 1901    Medicine
# 3    1901                      The Nobel Peace Prize 1901       Peace
# 4    1901                      The Nobel Peace Prize 1901       Peace
# ..    ...                                             ...         ...
# 906  2016  The Nobel Prize in Physiology or Medicine 2016    Medicine
# 907  2016                      The Nobel Peace Prize 2016       Peace
# 908  2016                 The Nobel Prize in Physics 2016     Physics
# 909  2016                 The Nobel Prize in Physics 2016     Physics
# 910  2016                 The Nobel Prize in Physics 2016     Physics
#
#          organization_country birth_date death_date  age
# 0                     Germany 1852-08-30 1911-03-01   58
# ...

# %%
import seaborn as sns

# %%
sns.scatterplot(x=data_age['year'], y=data_age['age'])
plt.xlabel(' ')
plt.ylabel('Age')
plt.title('Winners Age by Year')
# Out:
# Text(0.5, 1.0, 'Winners Age by Year')

# %% [markdown]
# <span style="font-size: 16px; color: black;">**YORUM:** Bu grafikte yılların ödül kazananların yaşıyla ilişkisinin çok da anlamlı olmadığını söyleyebilirim.Ödül kazanma yaşı yoğunluğu 65-90 arasındadır.<span/>

# %% [markdown]
#  <span style="font-size: 16px; color: blue;">6. 1938-1945 yılı arasında Nobel Ödülü kazananların kategorilerini ve ülkelerini görselleştirip yorumlayınız.<span/>

# %%
year_data=df[(df['year']>=1938)&(df['year']<=1945)]
year_data
# Out:
#      year    category                                           prize  \
# 197  1938   Chemistry               The Nobel Prize in Chemistry 1938
# 198  1938  Literature              The Nobel Prize in Literature 1938
# 199  1938    Medicine  The Nobel Prize in Physiology or Medicine 1938
# 200  1938       Peace                      The Nobel Peace Prize 1938
# 201  1938     Physics                 The Nobel Prize in Physics 1938
# 202  1939   Chemistry               The Nobel Prize in Chemistry 1939
# 203  1939   Chemistry               The Nobel Prize in Chemistry 1939
# 204  1939  Literature              The Nobel Prize in Literature 1939
# 205  1939    Medicine  The Nobel Prize in Physiology or Medicine 1939
# 206  1939     Physics                 The Nobel Prize in Physics 1939
# 207  1943   Chemistry               The Nobel Prize in Chemistry 1943
# 208  1943    Medicine  The Nobel Prize in Physiology or Medicine 1943
# ...

# %%
x=year_data['category']
y=year_data['organization_country']

# %%
year_data['organization_country'].fillna('Bilinmiyor', inplace=True)
year_data
# Out:
# C:\Users\HGA\AppData\Local\Temp\ipykernel_11092\3776485727.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   year_data['organization_country'].fillna('Bilinmiyor', inplace=True)
#      year    category                                           prize  \
# 197  1938   Chemistry               The Nobel Prize in Chemistry 1938
# 198  1938  Literature              The Nobel Prize in Literature 1938
# 199  1938    Medicine  The Nobel Prize in Physiology or Medicine 1938
# 200  1938       Peace                      The Nobel Peace Prize 1938
# 201  1938     Physics                 The Nobel Prize in Physics 1938
# 202  1939   Chemistry               The Nobel Prize in Chemistry 1939
# 203  1939   Chemistry               The Nobel Prize in Chemistry 1939
# ...

# %%
year_data_prize_count=year_data.groupby('category')['prize'].count()
year_data_prize_count
# Out:
# category
# Chemistry     6
# Literature    4
# Medicine      9
# Peace         3
# Physics       5
# Name: prize, dtype: int64

# %%
plt.figure(figsize=(8,4)) 
plt.bar(year_data_prize_count.index, year_data_prize_count.values,width=0.5 ,color='skyblue')
plt.xlabel(' ')
plt.ylabel('Prize Count') 
plt.title('Nobel Prize Winners Categories (1938-1945)') 
plt.show()

# %% [markdown]
# <span style="font-size: 16px; color: black;">**YORUM:** 1938-1945 yıllarıda en çok ödül alanı tıp iken en az barış alanı olmuş,ekonomi alanı bu tarihlerde henüz yok.<span/>

# %%
# 1938-1945 yıllarında ülke bazlı ödül sayılarını inceleyelim.

# %%
year_data_country=year_data.groupby('organization_country')['prize'].count()
year_data_country
# Out:
# organization_country
# Belgium                     1
# Bilinmiyor                  7
# Denmark                     1
# Finland                     1
# Germany                     4
# Italy                       1
# Sweden                      1
# Switzerland                 1
# United Kingdom              3
# United States of America    7
# Name: prize, dtype: int64

# %%
plt.figure(figsize=(8,4)) 
plt.bar(year_data_country.index, year_data_country.values,width=0.5 ,color='lightcoral')
plt.xlabel(' ')
plt.ylabel('Prize Count') 
plt.title('Nobel Prize Winners Countries (1938-1945)') 
plt.xticks(rotation=60)
plt.show()

# %% [markdown]
# <span style="font-size: 16px; color: black;">**YORUM:** 1938-1945 yıllarında en çok ödül alan ülkeler USA , organizasyon ülkesinin belirtilmediği ülkeler , Almanya ve UK  olmuş; diğerleri birer ödül almıştır.<span/>

# %% [markdown]
# <span style="font-size: 16px; color: blue;">7. 1947-1991 yılları arasında Nobel Ödülü kazananların kategorilerini ve ülkelerini görselleştirip yorumlayınız.(Her kategori için ayrı bir grafik olması istenmektedir)<span/>

# %%
year_data1=df[(df['year']>=1947)&(df['year']<=1991)]
x1=year_data1['category']
y1=year_data1['organization_country']
year_data1['organization_country'].fillna('Bilinmiyor', inplace=True)
year_data1
# Out:
# C:\Users\HGA\AppData\Local\Temp\ipykernel_11092\4204724065.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   year_data1['organization_country'].fillna('Bilinmiyor', inplace=True)
#      year    category                                           prize  \
# 232  1947   Chemistry               The Nobel Prize in Chemistry 1947
# 233  1947  Literature              The Nobel Prize in Literature 1947
# 234  1947    Medicine  The Nobel Prize in Physiology or Medicine 1947
# 235  1947    Medicine  The Nobel Prize in Physiology or Medicine 1947
# 236  1947    Medicine  The Nobel Prize in Physiology or Medicine 1947
# ..    ...         ...                                             ...
# 615  1991  Literature              The Nobel Prize in Literature 1991
# ...

# %%
year_data1.groupby('category').count()
# Out:
#             year  prize  motivation  prize_share  laureate_id  laureate_type  \
# category
# Chemistry     70     70          70           70           70             70
# Economics     31     31          31           31           31             31
# Literature    47     47          47           47           47             47
# Medicine     103    103         103          103          103            103
# Peace         46     46           3           46           46             46
# Physics       91     91          91           91           91             91
#
#             full_name  birth_date  birth_city  birth_country  sex  \
# category
# Chemistry          70          70          70             70   70
# Economics          31          31          31             31   31
# Literature         47          47          47             47   47
# Medicine          103         103         103            103  103
# Peace              46          35          35             35   35
# ...

# %%
plt.figure(figsize=(8,4))
x1.value_counts().plot(kind='bar', color='purple')
plt.title('Nobel Prize Winners Categories  (1947-1991)')
plt.xlabel(' ')
plt.ylabel('Prize Counts')
plt.xticks(rotation=0)
plt.show()

# %% [markdown]
# <span style="font-size: 16px; color: black;">**YORUM:** 1947-1991 yıllarında en çok ödül alınan alanların sıralaması yukardaki gibidir.Bu yıllarda bütün alanlarda ödüller alınmıştır.<span/>

# %%
# Kategorileri tek tek inceleyelim.

# %%
chemistry_data=year_data1[year_data1['category']=="Chemistry"]
chemistry_counts=chemistry_data.groupby('year')[['prize']].count()
chemistry_counts
# Out:
#       prize
# year
# 1947      1
# 1948      1
# 1949      1
# 1950      2
# 1951      2
# 1952      2
# 1953      1
# 1954      1
# 1955      1
# 1956      2
# 1957      1
# 1958      1
# 1959      1
# 1960      1
# 1961      1
# 1962      2
# 1963      2
# 1964      1
# 1965      1
# 1966      1
# 1967      3
# 1968      1
# 1969      2
# 1970      1
# 1971      1
# 1972      3
# 1973      2
# 1974      1
# 1975      2
# 1976      1
# 1977      1
# 1978      1
# 1979      2
# 1980      3
# 1981      2
# 1982      1
# 1983      1
# 1984      1
# 1985      2
# 1986      3
# 1987      3
# 1988      3
# 1989      2
# 1990      1
# 1991      1

# %%
plt.plot(chemistry_counts.index, chemistry_counts['prize'],color='blue', marker='o', linestyle='-')
plt.xlabel(' ')
plt.ylabel('Prize Counts')
plt.title('Chemistry Nobel Prizes (1947-1991)')
plt.xticks(range(1945, 2000, 5), rotation=45)
plt.show()

# %%
medicine_data=year_data1[year_data1['category']=="Medicine"]
medicine_counts=medicine_data.groupby('year')[['prize']].count()
medicine_counts
# Out:
#       prize
# year
# 1947      3
# 1948      1
# 1949      2
# 1950      3
# 1951      1
# 1952      1
# 1953      2
# 1954      3
# 1955      1
# 1956      3
# 1957      1
# 1958      3
# 1959      2
# 1960      2
# 1961      1
# 1962      3
# 1963      3
# 1964      2
# 1965      3
# 1966      2
# 1967      3
# 1968      3
# 1969      3
# 1970      3
# 1971      1
# 1972      2
# 1973      3
# 1974      3
# 1975      3
# 1976      2
# 1977      3
# 1978      3
# 1979      2
# 1980      3
# 1981      3
# 1982      3
# 1983      1
# 1984      3
# 1985      2
# 1986      2
# 1987      1
# 1988      3
# 1989      2
# 1990      2
# 1991      2

# %%
plt.plot(medicine_counts.index, medicine_counts['prize'],color='brown', marker='o', linestyle='-')
plt.xlabel(' ')
plt.ylabel('Prize Counts')
plt.title('Medicine Nobel Prizes (1947-1991)')
plt.xticks(range(1945, 2000, 5), rotation=45)
plt.show()

# %%
physics_data=year_data1[year_data1['category']=="Physics"]
physics_counts=physics_data.groupby('year')[['prize']].count()
physics_counts
# Out:
#       prize
# year
# 1947      1
# 1948      1
# 1949      1
# 1950      1
# 1951      2
# 1952      2
# 1953      1
# 1954      2
# 1955      2
# 1956      3
# 1957      2
# 1958      3
# 1959      2
# 1960      1
# 1961      2
# 1962      1
# 1963      3
# 1964      3
# 1965      3
# 1966      1
# 1967      1
# 1968      1
# 1969      1
# 1970      2
# 1971      1
# 1972      3
# 1973      3
# 1974      2
# 1975      3
# 1976      2
# 1977      3
# 1978      3
# 1979      3
# 1980      2
# 1981      3
# 1982      1
# 1983      2
# 1984      2
# 1985      1
# 1986      3
# 1987      2
# 1988      3
# 1989      3
# 1990      3
# 1991      1

# %%
plt.plot(physics_counts.index, physics_counts['prize'],color='darkgrey', marker='o', linestyle='-')
plt.xlabel(' ')
plt.ylabel('Prize Counts')
plt.title('Physics Nobel Prizes (1947-1991)')
plt.xticks(range(1945, 2000, 5), rotation=45)
plt.show()

# %%
literature_data=year_data1[year_data1['category']=="Literature"]
literature_counts=literature_data.groupby('year')[['prize']].count()
literature_counts
# Out:
#       prize
# year
# 1947      1
# 1948      1
# 1949      1
# 1950      1
# 1951      1
# 1952      1
# 1953      1
# 1954      1
# 1955      1
# 1956      1
# 1957      1
# 1958      1
# 1959      1
# 1960      1
# 1961      1
# 1962      1
# 1963      1
# 1964      1
# 1965      1
# 1966      2
# 1967      1
# 1968      1
# 1969      1
# 1970      1
# 1971      1
# 1972      1
# 1973      1
# 1974      2
# 1975      1
# 1976      1
# 1977      1
# 1978      1
# 1979      1
# 1980      1
# 1981      1
# 1982      1
# 1983      1
# 1984      1
# 1985      1
# 1986      1
# 1987      1
# 1988      1
# 1989      1
# 1990      1
# 1991      1

# %%
plt.plot(literature_counts.index, literature_counts['prize'],color='darkgreen', marker='o', linestyle='-')
plt.xlabel(' ')
plt.ylabel('Prize Counts')
plt.title('Literature Nobel Prizes (1947-1991)')
plt.xticks(range(1945, 2000, 5), rotation=45)
plt.show()

# %%
peace_data=year_data1[year_data1['category']=="Peace"]
peace_counts=peace_data.groupby('year')[['prize']].count()
peace_counts
# Out:
#       prize
# year
# 1947      2
# 1949      1
# 1950      1
# 1951      1
# 1952      1
# 1953      1
# 1954      1
# 1957      1
# 1958      1
# 1959      1
# 1960      1
# 1961      1
# 1962      1
# 1963      2
# 1964      1
# 1965      1
# 1968      1
# 1969      1
# 1970      1
# 1971      1
# 1973      2
# 1974      2
# 1975      1
# 1976      2
# 1977      1
# 1978      2
# 1979      1
# 1980      1
# 1981      1
# 1982      2
# 1983      1
# 1984      1
# 1985      1
# 1986      1
# 1987      1
# 1988      1
# 1989      1
# 1990      1
# 1991      1

# %%
plt.plot(peace_counts.index, peace_counts['prize'],color='navy', marker='o', linestyle='-')
plt.xlabel(' ')
plt.ylabel('Prize Counts')
plt.title('Peace Nobel Prizes (1947-1991)')
plt.xticks(range(1945, 2000, 5), rotation=45)
plt.show()

# %%
economics_data=year_data1[year_data1['category']=="Economics"]
economics_counts=economics_data.groupby('year')[['prize']].count()
economics_counts
# Out:
#       prize
# year
# 1969      2
# 1970      1
# 1971      1
# 1972      2
# 1973      1
# 1974      2
# 1975      2
# 1976      1
# 1977      2
# 1978      1
# 1979      2
# 1980      1
# 1981      1
# 1982      1
# 1983      1
# 1984      1
# 1985      1
# 1986      1
# 1987      1
# 1988      1
# 1989      1
# 1990      3
# 1991      1

# %%
plt.plot(economics_counts.index, economics_counts['prize'],color='red', marker='o', linestyle='-')
plt.xlabel(' ')
plt.ylabel('Prize Counts')
plt.title('Economics Nobel Prizes (1947-1991)')
plt.xticks(range(1945, 2000, 5), rotation=45)
plt.show()

# %%
# 1947-1991 yıllarında ödül kazanan ülkeleri inceleyelim.

# %%
year_data1=df[(df['year']>=1947)&(df['year']<=1991)]
y1=year_data1['organization_country']
plt.figure(figsize=(14,6))
y1.value_counts().plot(kind='bar',width=0.6 , color='darkblue')
plt.title('Nobel Prize Winners Countries (1947-1991)')
plt.xlabel(' ')
plt.ylabel('Prize')
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# <span style="font-size: 16px; color: black;">**YORUM:** 1947-1991 yıllarında en çok ödül kazanan ülke açık ara farkla USA olmuş,Almanya bu tarihlerde savaşta uyguladığı politikalarla önemli vatandaşlarının USA ya göçmesiyle ödül alamamıştır.<span/>

# %% [markdown]
# <span style="font-size: 16px; color: blue;">8. Kimya, Edebiyat, Barış, Fizik ve Tıp kategorilerindeki 2000 sonrasındaki kişilerin ülkelerini, yaşlarını görselleştirin.(Her bir Kategori için ayrı görselleştirme yapılması istenmektedir) Veriyi yorumlayınız.<span/>

# %%
# 2000 sonrasında ödül kazananların kategorilerini tek tek inceleyelim.

# %%
last_data=data_age[data_age['year']>2000]
last_data
# Out:
#      year                                              prize   category  \
# 719  2001                  The Nobel Prize in Chemistry 2001  Chemistry
# 720  2001                  The Nobel Prize in Chemistry 2001  Chemistry
# 721  2001                  The Nobel Prize in Chemistry 2001  Chemistry
# 722  2001  The Sveriges Riksbank Prize in Economic Scienc...  Economics
# 723  2001  The Sveriges Riksbank Prize in Economic Scienc...  Economics
# ..    ...                                                ...        ...
# 906  2016     The Nobel Prize in Physiology or Medicine 2016   Medicine
# 907  2016                         The Nobel Peace Prize 2016      Peace
# 908  2016                    The Nobel Prize in Physics 2016    Physics
# 909  2016                    The Nobel Prize in Physics 2016    Physics
# 910  2016                    The Nobel Prize in Physics 2016    Physics
#
#          organization_country birth_date death_date  age
# ...

# %%
last_data['organization_country'].fillna('Bilinmiyor', inplace=True)
# Out:
# C:\Users\HGA\AppData\Local\Temp\ipykernel_11092\1091030099.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   last_data['organization_country'].fillna('Bilinmiyor', inplace=True)

# %%
last_data
# Out:
#      year                                              prize   category  \
# 719  2001                  The Nobel Prize in Chemistry 2001  Chemistry
# 720  2001                  The Nobel Prize in Chemistry 2001  Chemistry
# 721  2001                  The Nobel Prize in Chemistry 2001  Chemistry
# 722  2001  The Sveriges Riksbank Prize in Economic Scienc...  Economics
# 723  2001  The Sveriges Riksbank Prize in Economic Scienc...  Economics
# ..    ...                                                ...        ...
# 906  2016     The Nobel Prize in Physiology or Medicine 2016   Medicine
# 907  2016                         The Nobel Peace Prize 2016      Peace
# 908  2016                    The Nobel Prize in Physics 2016    Physics
# 909  2016                    The Nobel Prize in Physics 2016    Physics
# 910  2016                    The Nobel Prize in Physics 2016    Physics
#
#          organization_country birth_date death_date  age
# ...

# %%
data_category=last_data.groupby('category').count()
data_category
# Out:
#             year  prize  organization_country  birth_date  death_date  age
# category
# Chemistry     39     39                    39          39          39   39
# Economics     32     32                    32          32          32   32
# Literature    16     16                    16          16          16   16
# Medicine      39     39                    39          39          39   39
# Peace         16     16                    16          16          16   16
# Physics       41     41                    41          41          41   41

# %%
che_data=last_data[last_data['category']=="Chemistry"]
che_counts=che_data.groupby('organization_country')['prize'].count()
che_counts
# Out:
# organization_country
# Bilinmiyor                   1
# France                       3
# Germany                      2
# Israel                       4
# Japan                        3
# Netherlands                  1
# Switzerland                  1
# United Kingdom               1
# United States of America    23
# Name: prize, dtype: int64

# %%
plt.figure(figsize=(10,4)) 
plt.bar(che_counts.index, che_counts.values,width=0.5 ,color='lightcoral')
plt.xlabel(' ')
plt.ylabel('Chemistry Prize Count') 
plt.title('Nobel Prize Winners Countries (2000 -  ...)') 
plt.xticks(rotation=60)
plt.show()

# %% [markdown]
# <span style="font-size: 16px; color: black;">**YORUM:** 2000 sonrasında da en çok ödül alan ülke USA fakat burada İsrail de dikkat çekmiş kimya alanında çalışmalarını arttırmış olabilir.<span/>

# %%
lit_data=last_data[last_data['category']=="Literature"]
lit_counts=lit_data.groupby('organization_country')['prize'].count()
lit_counts
# Out:
# organization_country
# Bilinmiyor    16
# Name: prize, dtype: int64

# %%
plt.figure(figsize=(10,4)) 
plt.bar(lit_counts.index, lit_counts.values,width=0.1,color='lightcoral')
plt.xlabel(' ')
plt.ylabel('Literature Prize Count') 
plt.title('Nobel Prize Winners Countries (2000 -  ...)') 
plt.xticks(rotation=60)
plt.show()

# %% [markdown]
# <span style="font-size: 16px; color: black;">**YORUM:** 2000 sonrasında edebiyat alanında sadece organizasyon ülkesi belirtilmemiş olan ülkeler ödül kazanmıştır.<span/>

# %%
pea_data=last_data[last_data['category']=="Peace"]
pea_counts=pea_data.groupby('organization_country')['prize'].count()
pea_counts
# Out:
# organization_country
# Bilinmiyor    16
# Name: prize, dtype: int64

# %%
plt.figure(figsize=(10,4)) 
plt.bar(pea_counts.index, pea_counts.values,width=0.1,color='lightcoral')
plt.xlabel(' ')
plt.ylabel('Peace Prize Count') 
plt.title('Nobel Prize Winners Countries (2000 -  ...)') 
plt.xticks(rotation=60)
plt.show()

# %% [markdown]
# <span style="font-size: 16px; color: black;">**YORUM:** 2000 sonrasında barış alanında sadece organizasyon ülkesi belirtilmemiş olan ülkeler ödül kazanmıştır.<span/>

# %%
phy_data=last_data[last_data['category']=="Physics"]
phy_counts=phy_data.groupby('organization_country')['prize'].count()
phy_counts
# Out:
# organization_country
# Australia                    1
# Belgium                      1
# Canada                       1
# France                       2
# Germany                      2
# Japan                        6
# Russia                       1
# United Kingdom               4
# United States of America    23
# Name: prize, dtype: int64

# %%
plt.figure(figsize=(10,4)) 
plt.bar(phy_counts.index, phy_counts.values,width=0.5,color='lightcoral')
plt.xlabel(' ')
plt.ylabel('Physics Prize Count') 
plt.title('Nobel Prize Winners Countries (2000 -  ...)') 
plt.xticks(rotation=60)
plt.show()

# %% [markdown]
# <span style="font-size: 16px; color: black;">**YORUM:** 2000 sonrasında en çok fizik ödülü kazanan gene USA olmuş fakat burada Japonyada iyi bir artış olmuş İngiltere ve Almanyayı gerisinde bırakmıştır.<span/>

# %%
med_data=last_data[last_data['category']=="Medicine"]
med_counts=med_data.groupby('organization_country')['prize'].count()
med_counts
# Out:
# organization_country
# Australia                    2
# China                        1
# France                       3
# Germany                      1
# Japan                        3
# Norway                       2
# United Kingdom               8
# United States of America    19
# Name: prize, dtype: int64

# %%
plt.figure(figsize=(10,4)) 
plt.bar(med_counts.index, med_counts.values,width=0.5,color='lightcoral')
plt.xlabel(' ')
plt.ylabel('Medicine Prize Count') 
plt.title('Nobel Prize Winners Countries (2000 -  ...)') 
plt.xticks(rotation=60)
plt.show()

# %% [markdown]
# <span style="font-size: 16px; color: black;">**YORUM:** 2000 sonrasında en çok tıp ödülü kazanan USA olmuş İngiltere, Japonya , Fransa onu takip etmiştir.<span/>

# %%
# 2000 sonrası nobel ödülü kazananların yaşlarını inceleyelim.

# %%
sns.scatterplot(x=last_data['year'], y=last_data['age'])
plt.xlabel(' ')
plt.ylabel('Age')
plt.title('Winners Age ( 2000 - ...)')
# Out:
# Text(0.5, 1.0, 'Winners Age ( 2000 - ...)')

# %% [markdown]
# <span style="font-size: 16px; color: black;">**YORUM:** Bu grafikte yılların ödül kazananların yaşıyla ilişkisinin çok da anlamlı olmadığını söyleyebilirim.Ödül kazanma yaşı yoğunluğu hala 65 üzeri iken 2014 te alınan ödülün sahibi Malala Yousafzai en genç Nobel ödülü sahibi kişi olarak tarihe geçmiştir.<span/>
